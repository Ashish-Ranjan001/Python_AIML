# %%
import pandas as pd 
dataset = pd.read_csv('Lr.csv')

# %%
dataset.head(4)
# Out:
#       x          y
# 0  24.0  21.549452
# 1  50.0  47.464463
# 2  15.0  17.218656
# 3  38.0  36.586398

# %%
dataset.isnull().sum()
# Out:
# x    0
# y    1
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       700 non-null    float64
#  1   y       699 non-null    float64
# dtypes: float64(2)
# memory usage: 11.1 KB

# %%
dataset.shape
# Out:
# (700, 2)

# %%
dataset.fillna(dataset.mean(), inplace=True)

# %%
dataset.isnull().sum()  # Corrected typo from 'dataset' to 'datset'
# Out:
# x    0
# y    0
# dtype: int64

# %% [markdown]
# Now My data has no missing values and my whole data is cleand and its ready to be used for the regression

# %%
#Linar Regression

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = dataset['y']
y= dataset['x']
plt.scatter(x, y)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train.values.reshape(-1, 1), y_train.values)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test.values.reshape(-1, 1))

# %%
from sklearn.metrics import mean_squared_error, r2_score

print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("R² Score:", r2_score(y_test, y_pred))
# Out:
# Mean Squared Error: 48.22203285821746
# R² Score: 0.9484463267924835

# %%
plt.scatter(x_test, y_test, color='blue', label='Actual')
plt.plot(x_test, y_pred, color='red', linewidth=2, label='Predicted')
plt.xlabel('Feature')
plt.ylabel('Target')
plt.title('Linear Regression Results')
plt.legend()
plt.show()
